# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from matplotlib import font_manager, rc
rc('font', family='AppleGothic')

# %%
df = pd.read_csv('../../../05000266/part4/auto-mpg.csv', header = None)
df.columns = ['mpg','cylinders','displacement','horsepower','weight','acceleration','model year','origin','name']
df
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0      130.0  3504.0          12.0
# 1    15.0          8         350.0      165.0  3693.0          11.5
# 2    18.0          8         318.0      150.0  3436.0          11.0
# 3    16.0          8         304.0      150.0  3433.0          12.0
# 4    17.0          8         302.0      140.0  3449.0          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0      86.00  2790.0          15.6
# 394  44.0          4          97.0      52.00  2130.0          24.6
# 395  32.0          4         135.0      84.00  2295.0          11.6
# 396  28.0          4         120.0      79.00  2625.0          18.6
# 397  31.0          4         119.0      82.00  2720.0          19.4
#
#      model year  origin                       name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
# fig, ax = plt.subplots(1,2, figsize=(15,5))
plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
plt.boxplot(
    x = [
        df[df['origin']==1]['mpg'],
        df[df['origin']==2]['mpg'],
        df[df['origin']==3]['mpg']
    ],
    labels = ['USA', 'EU', 'JAPAN']
)

plt.subplot(1,2,2)
plt.boxplot(
    x = [
        df[df['origin']==1]['mpg'],
        df[df['origin']==2]['mpg'],
        df[df['origin']==3]['mpg']
    ],
    labels = ['USA', 'EU', 'JAPAN'],
    vert = False
)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7ffd2f0be1c0>,
#   <matplotlib.lines.Line2D at 0x7ffd2f0be520>,
#   <matplotlib.lines.Line2D at 0x7ffd2f0c99a0>,
#   <matplotlib.lines.Line2D at 0x7ffd2f0c9d00>,
#   <matplotlib.lines.Line2D at 0x7ffd2f0e01c0>,
#   <matplotlib.lines.Line2D at 0x7ffd2f0e0520>],
#  'caps': [<matplotlib.lines.Line2D at 0x7ffd2f0be880>,
#   <matplotlib.lines.Line2D at 0x7ffd2f0bebe0>,
#   <matplotlib.lines.Line2D at 0x7ffd2f0d50a0>,
#   <matplotlib.lines.Line2D at 0x7ffd2f0d5400>,
#   <matplotlib.lines.Line2D at 0x7ffd2f0e08b0>,
#   <matplotlib.lines.Line2D at 0x7ffd2f0e0c10>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7ffd2f036e20>,
#   <matplotlib.lines.Line2D at 0x7ffd2f0c9640>,
#   <matplotlib.lines.Line2D at 0x7ffd2f0d5e20>],
#  'medians': [<matplotlib.lines.Line2D at 0x7ffd2f0bef40>,
#   <matplotlib.lines.Line2D at 0x7ffd2f0d5760>,
#   <matplotlib.lines.Line2D at 0x7ffd2f0e0f70>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7ffd2f0c92e0>,
#   <matplotlib.lines.Line2D at 0x7ffd2f0d5ac0>,
#   <matplotlib.lines.Line2D at 0x7ffd2f0ed310>],
#  'means': []}
