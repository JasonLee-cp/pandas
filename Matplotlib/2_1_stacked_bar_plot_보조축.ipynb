# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from matplotlib import font_manager, rc

rc('font', family='AppleGothic')
df = pd.read_excel('../../../05000266/part4/남북한발전전력량.xlsx', engine='openpyxl', header=0)
df
# Out:
#   전력량 (억㎾h) 발전 전력별  1990  1991  1992  1993  1994  1995  1996  1997  ...  2007  \
# 0        남한     합계  1077  1186  1310  1444  1650  1847  2055  2244  ...  4031
# 1       NaN     수력    64    51    49    60    41    55    52    54  ...    50
# 2       NaN     화력   484   573   696   803  1022  1122  1264  1420  ...  2551
# 3       NaN    원자력   529   563   565   581   587   670   739   771  ...  1429
# 4       NaN    신재생     -     -     -     -     -     -     -     -  ...     -
# 5        북한     합계   277   263   247   221   231   230   213   193  ...   236
# 6       NaN     수력   156   150   142   133   138   142   125   107  ...   133
# 7       NaN     화력   121   113   105    88    93    88    88    86  ...   103
# 8       NaN    원자력     -     -     -     -     -     -     -     -  ...     -
#
#    2008  2009  2010  2011  2012  2013  2014  2015  2016
# 0  4224  4336  4747  4969  5096  5171  5220  5281  5404
# 1    56    56    65    78    77    84    78    58    66
# ...

# %%
# 북한
df = df.loc[5:]
df
# Out:
#   전력량 (억㎾h) 발전 전력별 1990 1991 1992 1993 1994 1995 1996 1997  ... 2007 2008  \
# 5        북한     합계  277  263  247  221  231  230  213  193  ...  236  255
# 6       NaN     수력  156  150  142  133  138  142  125  107  ...  133  141
# 7       NaN     화력  121  113  105   88   93   88   88   86  ...  103  114
# 8       NaN    원자력    -    -    -    -    -    -    -    -  ...    -    -
#
#   2009 2010 2011 2012 2013 2014 2015 2016
# 5  235  237  211  215  221  216  190  239
# 6  125  134  132  135  139  130  100  128
# 7  110  103   79   80   82   86   90  111
# 8    -    -    -    -    -    -    -    -
#
# [4 rows x 29 columns]

# %%
# drop unncessary columns
df.drop('전력량 (억㎾h)', axis = 1, inplace=True)
# Out:
# /Users/jasonlee/Desktop/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df
# Out:
#        1990 1991 1992 1993 1994 1995 1996 1997 1998 1999  ... 2007 2008 2009  \
# 발전 전력별                                                    ...
# 합계      277  263  247  221  231  230  213  193  170  186  ...  236  255  235
# 수력      156  150  142  133  138  142  125  107  102  103  ...  133  141  125
# 화력      121  113  105   88   93   88   88   86   68   83  ...  103  114  110
# 원자력       -    -    -    -    -    -    -    -    -    -  ...    -    -    -
#
#        2010 2011 2012 2013 2014 2015 2016
# 발전 전력별
# 합계      237  211  215  221  216  190  239
# 수력      134  132  135  139  130  100  128
# 화력      103   79   80   82   86   90  111
# 원자력       -    -    -    -    -    -    -
#
# [4 rows x 27 columns]

# %%
df.set_index('발전 전력별', inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-6a2b5f156248> in <module>
# ----> 1 df.set_index('발전 전력별', inplace = True)
#
# ~/Desktop/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4725
#    4726         if missing:
# -> 4727             raise KeyError(f"None of {missing} are in the columns")
#    4728
#    4729         if inplace:
#
# KeyError: "None of ['발전 전력별'] are in the columns"

# %%
df
# Out:
#        1990 1991 1992 1993 1994 1995 1996 1997 1998 1999  ... 2007 2008 2009  \
# 발전 전력별                                                    ...
# 합계      277  263  247  221  231  230  213  193  170  186  ...  236  255  235
# 수력      156  150  142  133  138  142  125  107  102  103  ...  133  141  125
# 화력      121  113  105   88   93   88   88   86   68   83  ...  103  114  110
# 원자력       -    -    -    -    -    -    -    -    -    -  ...    -    -    -
#
#        2010 2011 2012 2013 2014 2015 2016
# 발전 전력별
# 합계      237  211  215  221  216  190  239
# 수력      134  132  135  139  130  100  128
# 화력      103   79   80   82   86   90  111
# 원자력       -    -    -    -    -    -    -
#
# [4 rows x 27 columns]

# %%
df = df.T

# %%
df.head()
# Out:
# 발전 전력별   합계   수력   화력 원자력
# 1990    277  156  121   -
# 1991    263  150  113   -
# 1992    247  142  105   -
# 1993    221  133   88   -
# 1994    231  138   93   -

# %%
df.drop('원자력', axis = 1, inplace = True)

# %%
df.head()
# Out:
# 발전 전력별   합계   수력   화력
# 1990    277  156  121
# 1991    263  150  113
# 1992    247  142  105
# 1993    221  133   88
# 1994    231  138   93

# %%
df = df.rename(columns={'합계':'총발전량'})

# %%
df.head()
# Out:
# 발전 전력별 총발전량   수력   화력
# 1990    277  156  121
# 1991    263  150  113
# 1992    247  142  105
# 1993    221  133   88
# 1994    231  138   93

# %%
df['총발전량 - 1년'] = df['총발전량'].shift(1)
df.head()
# Out:
# 발전 전력별 총발전량   수력   화력 총발전량 - 1년
# 1990    277  156  121       NaN
# 1991    263  150  113       277
# 1992    247  142  105       263
# 1993    221  133   88       247
# 1994    231  138   93       221

# %%
df['증감률'] = ((df['총발전량'] / df['총발전량 - 1년']) - 1) * 100

# %%
df.head()
# Out:
# 발전 전력별 총발전량   수력   화력 총발전량 - 1년        증감률
# 1990    277  156  121       NaN        NaN
# 1991    263  150  113       277  -5.054152
# 1992    247  142  105       263   -6.08365
# 1993    221  133   88       247 -10.526316
# 1994    231  138   93       221   4.524887

# %%
ax1 = df[['수력', '화력']].plot(kind='bar', figsize=(20,10), width=0.7, stacked = True)
ax2 = ax1.twinx()
ax2.plot(df.index, df.증감률, ls='--', marker='o', markersize=20, color='green', label='전년대비 증감률 (%)')

ax1.set_ylim(0, 500)
ax2.set_ylim(-50,50)

ax1.set_xlabel('연도',size=20)
ax1.set_ylabel('발전량(억 kWh)')
ax2.set_ylabel('전년 대비 증감률(%)')

plt.title('북한 전력 발전량 (1990-2016)', size=30)
ax1.legend(loc='upper left')

plt.show()
# Out:
# /Users/jasonlee/Desktop/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /Users/jasonlee/Desktop/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 8722 missing from current font.
#   font.set_text(s, 0, flags=flags)
